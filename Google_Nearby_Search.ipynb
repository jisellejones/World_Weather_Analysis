# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "location" : "48.8566, 2.3522",
    "radius" : 5000, 
    "types" : "lodging",
    "key" : g_key
    
}



#Use base URL to search for hotels in Paris.
#base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
#hotels = requests.get(base_url, params=params).json()

#print(hotels)
# Out:
# {'html_attributions': [], 'next_page_token': 'Aap_uECWnxWKBKIT5SZZT_wkA5yoLS44kgFRChP7IH_htY7KkCesNNkBE8KJ0BgHoDF9FziYIeGWpa-k6IJzWdtw71flMBKcZrJciDWTiGND3eJMOxiHlYkKetAdiIS0ZbW2JdrK__BuKBY9fYmYA7IMeZtudPBEUmyc3szpAwX-AK_CPpj2N89oQ-SIHLAcfzLr-o--C87MjOzvUYbpa4aVoTmo4f4o1mMWMbN4KTFZSxwMYVsqgDZQ6ztpqmsU28PNkYd2vgAhO1_NTLsXPwJGvNOXjWALTV1V1Agq8F4M5DSYugBelrx0XVgpt-QiTIU_2FoIjV_Vs6CUhkIIooxKgXhoUOcfW-rnKkFodwq71LI1N1tsrHS8raMagJqJyYddW3amz6rafazvlAmJilfnfLZlLVJ40D2iDgRBlhUJeu0CyJLeF8lrOxjG', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277}, 'viewport': {'northeast': {'lat': 48.8594393802915, 'lng': 2.354352980291503}, 'southwest': {'lat': 48.8567414197085, 'lng': 2.351655019708499}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'name': 'Hôtel Duo', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3840, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'], 'photo_reference': 'Aap_uEDwIaE_-6C4WdvtfaYUe2KutI_-CqhZAru_IK37-Ld9muosxvhXELQfDkPDvAydNuvfhSAzpoEJ9iNiGZ63K4i_tiWdl2SmiGJV_pbv_VUcIPO7BTeK1KIKKmktpv_tCOLVLeOdF_OxZ2aCguOq-nI1naEkq3shhXJgi2ko6fiE1Xqq', 'width': 5760}], 'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc', 'plus_code': {'compound_code': 'V953+65 Paris, France', 'global_code': '8FW4V953+65'}, 'rating': 4.2, 'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc', 'scope': 'GOOGLE', 'types': ['night_club', 'spa', 'lodging', 'bar', 'gym', 'health', 'point_of_interest', 'establishment'], 'user_ratings_total': 284, 'vicinity': '11 Rue du Temple, Paris'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944}, 'viewport': {'northeast': {'lat': 48.8595495802915, 'lng': 2.347780980291502}, 'southwest': {'lat': 48.8568516197085, 'lng': 2.345083019708498}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'name': 'Hôtel Britannique - Paris Centre', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3168, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'], 'photo_reference': 'Aap_uED0yCszGPJzzpqMyrwuDG5uYb9FdrF88Tk3j_8dsmgAh6bWFrgOx5tc2fX3dsHLeUvWyxbM9cZwUds-WUiUP3hxOonxaObQYNBAcieLhqwbhFE8rwfBD7QpNCfxP3dMA7N2D5JMykCRICg2oSFOcE_jOK52D5FSQxGe7sMu64U9Fcoc', 'width': 4752}], 'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU', 'plus_code': {'compound_code': 'V85W+8H Paris, France', 'global_code': '8FW4V85W+8H'}, 'rating': 4.6, 'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 563, 'vicinity': '20 Avenue Victoria, Paris'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293}, 'viewport': {'northeast': {'lat': 48.86176813029151, 'lng': 2.348251430291502}, 'southwest': {'lat': 48.85907016970851, 'lng': 2.345553469708498}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'name': 'Citadines Les Halles Paris', 'opening_hours': {'open_now': True}, 'photos': [{'height': 849, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart hotel Paris)</a>'], 'photo_reference': 'Aap_uEDSiP9mUvosI2lb76-0FM0SmIss4OMM6XqTw-v4d7bv13T-D1Dwm797iE74-8tNMTc6sYZmKqzK5bZ8fLTG4dSjD1MkafaOxAXZDRIouMsKniYcsb7nBzmwOW2Ur6g3tgKsvSJWIA_bAz1vzNiILKlkZkw0YKIDj--6kqlXKcx3BRlo', 'width': 1280}], 'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU', 'plus_code': {'compound_code': 'V86W+7Q Paris, France', 'global_code': '8FW4V86W+7Q'}, 'rating': 4.1, 'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 824, 'vicinity': '4 Rue des Innocents, Paris'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8607658, 'lng': 2.3465318}, ...

# %%
len(hotels["results"])
# Out:
# 20

# %%
hotels["results"][0]["name"]
# Out:
# 'Hôtel Duo'
